# %% [markdown]
# # Hello World
#
# Hello world is the most basic Python code. This simply writes on console "Hello world."

# %%
print('Hello world.')
# Out:
# Hello world.

# %% [markdown]
# ## Pseudorandom Numbers
#
# [Python `random` module](https://docs.python.org/3.14/library/random.html) supports psedorandom number generators.
#
# This program returns a random integer `n` which fulfils the following relation.
# $$
# 0 \leq n < 100
# $$

# %%
import random
random.randrange(0, 100)
# Out:
# 34

# %% [markdown]
# ## Basic Operations
#
# The addition, subtraction, multplitation, and division operations are expressed by the operators, `+`, `-`, `*`, and `/`, respectively.

# %%
a = 2
b = 4
a + b
# Out:
# 6

# %%
a - b
# Out:
# -2

# %%
a * b
# Out:
# 8

# %%
b / a
# Out:
# 2.0

# %% [markdown]
# ## Appendix
#
# ### Variable Locations
#
# Variables are stored in the designated locations. The locations are aceessible with `id` built-in function.

# %%
id(a)
# Out:
# 140732563571864
